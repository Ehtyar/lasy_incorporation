# %%
import ptime

import showdata
import numpy as np
start = "/bigdata/hplsim/production/marqua27/"
end = "/simOutput/openPMD/simData_%T.bp"
filename = start+"vacuum_propagation/flfoc_102_PIC_big"+end

# %%
showdata.show_file(filename, itstep=1, forward="y", show_time=True, linthresh_frac=1)
ptime.ptime()
# Out:
# iteration: 2000
# absolute maximum: 304246650000.0
# time showing file: 3 s 708 ms
# iteration: 1135454
# absolute maximum: 2337637700000.0
# time showing file: 41 s 2 ms
# iteration: 1137454
# absolute maximum: 2335831000000.0
# time showing file: 45 s 529 ms
# iteration: 1139454
# absolute maximum: 2333691300000.0
# time showing file: 50 s 385 ms
# iteration: 1141454
# absolute maximum: 2330312000000.0
# time showing file: 53 s 634 ms
# iteration: 1143454
# absolute maximum: 2325677600000.0
# time showing file: 58 s 137 ms
# iteration: 1145454
# absolute maximum: 2319856700000.0
# time showing file: 1 min 1 s 630 ms
# iteration: 1147454
# absolute maximum: 2313033000000.0
# time showing file: 1 min 6 s 315 ms
# iteration: 1149454
# absolute maximum: 2304942300000.0
# time showing file: 1 min 9 s 720 ms
# iteration: 1151454
# absolute maximum: 2295552000000.0
# time showing file: 1 min 14 s 101 ms
# iteration: 1153454
# absolute maximum: 2293090700000.0
# ...

# %%
from scipy.constants import c
import axiparabola_theory as axi
from lasy.optical_elements import Axiparabola
delta = 2e-3
f0 = 7e-2
w = 1e-3
R = 1.*w

# %%
# showdata.show_metadata(filename, iteration=6000)

def shouldbe(t):
    """theoretical w"""
    l_w = 10.54e-7
    return axi.wtf(t, Axiparabola(f0, delta, R), l_w)
showdata.plot_w(filename=filename, forward="y", startit=1137453, comp_func=shouldbe, maxtime=axi.tfz((f0+delta) * (1-1e-7), Axiparabola(f0, delta, R)))
ptime.ptime()
# Out:
# calculating w
#   0%|          | 00:00<? [?it/s]
# maxtime reached
# plotting w
# runtime: 34 min 29 s 435 ms

# %%
def shouldbe2(t):
    """theoretical value"""
    l_w = 10.54e-7
    tau = 1.5e-14
    return 0.02*c*(t-f0/c)
showdata.plot_lpeak(filename=filename, forward="y", startit=1137453, 
                    comp_func=shouldbe2, maxtime=axi.tfz((f0+delta) * (1-2e-7), Axiparabola(f0, delta, R)),
                   apply_maxtime_to_measurement=True)
ptime.ptime()
# Out:
# calculating lpeak
#   0%|          | 00:00<? [?it/s]
# maxtime reached
# plotting lpeak
# runtime: 1 h 6 min 58 s 860 ms
