# %%
import time
start = time.time()

from lasy.laser import Laser
from lasy.profiles.gaussian_profile import GaussianProfile
from lasy.optical_elements import ParabolicMirror
from lasy.utils.laser_utils import get_w0
from lasy.utils.grid import Grid

import numpy as np
import matplotlib.pyplot as plt
from scipy.constants import c

import full_field
import axiparabola_theory as axi

dim = "rt"

# %%
l_w = 10.54e-7
f0 = 7e-2
delta = 5e-3
w = 1e-3
tau = 1.5e-14
E = 6.2
des_dt = 1.39e-16 # PIConGPU Standardwert
des_dt = 7.3443e-17 # spezieller Wert
w0 = f0 * l_w / w / np.pi
vf = 0.98 * c
print("w0 =", w0)
print("w/w0 =",w/w0)
if dim == "xyt":
    npoints = (int(2*w/w0), int(2*w/w0), 200)
    npoints_prop = (int(10*w/w0), int(10*w/w0), 200)
    hi = (1.1*w, 1.1*w, 4.5*tau)
    lo = (-1.1*w, -1.1*w, -5.*tau)
elif dim == "rt":
    p_per_r = 1.0/3
    picpoints_per_p = 2
    print("points in file:", int(1024/picpoints_per_p))
    spacing = 0.1772e-6 * p_per_r * 6 # PIConGPU Standardwert
    npoints = (int(2*w/spacing), 3000)
    cut_frac = 0.3
    hi = (2*w, 21*tau)
    lo = (0., -15*tau)
    offset_frac = hi[1]/4 / (hi[1]-lo[1])
    print(offset_frac)
print(npoints)

print(np.pi*w0**2/l_w)
print(100000*des_dt*c)

print("time:", (time.time()-start)/60, "min")
# Out:
# w0 = 2.3484903402640077e-05
# w/w0 = 42.580545589452335
# points in file: 512
# 0.14583333333333334
# (5643, 3000)
# 0.0016439432381848056
# 0.0022017657492894005
# time: 0.025476654370625813 min

# %%
profile = GaussianProfile(l_w, (1,0), E, w, tau, 0.0)
laser = Laser(dim, lo, hi, npoints, profile)
print("time:", (time.time()-start)/60, "min")
# Out:
# time: 0.102260160446167 min

# %%
axiparabola = axi.Axiparabola_Ambat(f0, delta, w)
laser.apply_optics(axiparabola)
laser.show()
print("time:", (time.time()-start)/60, "min")
# Out:
# time: 0.2081033984820048 min

# %%
zr = np.pi * w0**2 / l_w
l = f0 - zr
print(l)
newGrid = Grid(laser.dim, (0., -1e-13), (1e-3, 1e-13), npoints, n_azimuthal_modes=1)
laser.propagate(l, grid_out=newGrid)
full_field.show_field(laser, linthresh_frac=0.001, title="At the Rayleigh distance")
laser.show()
print("time:", (time.time()-start)/60, "min")
# Out:
# 0.0683560567618152
# Available backends are: NP
# NP is chosen
#   0%|          | 00:00<? [?it/s]
# Extracting full field
# Displaying
# time: 13.14995881319046 min

# %%
N = 20
ws = np.zeros(N+1)
wes = np.zeros(N+1)
wps = np.zeros(N+1)
zs = np.zeros(N+1)
ts = np.zeros(N+1)
tes = np.zeros(N+1)

ws[0] = get_w0(laser.grid, laser.dim)
zs[0] = l
tps = full_field.get_tpeak(laser)
dist = (zr+delta*(1-1e-7))/N
Nmin = 0

# %%
for n in range(N):
    print(f"Step {n+1} of {N}:")
    laser.propagate(dist)
    laser.show()
    ws[n+1] = get_w0(laser.grid, laser.dim)
    zs[n+1] = l + (n+1)*dist
    if zs[n+1] > f0:
        if Nmin == 0:
            Nmin = n+1
        wes[n+1] = axi.wz(zs[n+1], axiparabola, l_w)
        tes[n+1] = axi.tfz(zs[n+1], axiparabola)-zs[n+1]/c
    ts[n+1] = full_field.get_tpeak(laser) - tps
    print("time:", (time.time()-start)/60, "min")
# Out:
# Step 1 of 20:
# Available backends are: NP
# NP is chosen
#   0%|          | 00:00<? [?it/s]
# time: 24.737701749801637 min
# Step 2 of 20:
#   0%|          | 00:00<? [?it/s]
# time: 35.13278944094976 min
# Step 3 of 20:
#   0%|          | 00:00<? [?it/s]
# time: 45.51921225388845 min
# Step 4 of 20:
#   0%|          | 00:00<? [?it/s]
# time: 55.951051998138425 min
# Step 5 of 20:
#   0%|          | 00:00<? [?it/s]
# time: 66.3441143711408 min
# Step 6 of 20:
#   0%|          | 00:00<? [?it/s]
# time: 76.70714750687281 min
# Step 7 of 20:
#   0%|          | 00:00<? [?it/s]
# time: 87.08100424607595 min
# Step 8 of 20:
#   0%|          | 00:00<? [?it/s]
# time: 97.47231990893683 min
# Step 9 of 20:
#   0%|          | 00:00<? [?it/s]
# time: 107.86031763156255 min
# Step 10 of 20:
#   0%|          | 00:00<? [?it/s]
# time: 118.26919263601303 min
# Step 11 of 20:
#   0%|          | 00:00<? [?it/s]
# time: 128.6678682923317 min
# Step 12 of 20:
#   0%|          | 00:00<? [?it/s]
# time: 139.0647170305252 min
# Step 13 of 20:
#   0%|          | 00:00<? [?it/s]
# time: 149.47578304608663 min
# Step 14 of 20:
#   0%|          | 00:00<? [?it/s]
# time: 159.83658771912258 min
# Step 15 of 20:
#   0%|          | 00:00<? [?it/s]
# time: 170.2132502555847 min
# Step 16 of 20:
#   0%|          | 00:00<? [?it/s]
# time: 180.58039991458256 min
# Step 17 of 20:
#   0%|          | 00:00<? [?it/s]
# time: 190.99991233348845 min
# Step 18 of 20:
#   0%|          | 00:00<? [?it/s]
# time: 201.46117986440657 min
# Step 19 of 20:
#   0%|          | 00:00<? [?it/s]
# time: 211.8612831234932 min
# Step 20 of 20:
#   0%|          | 00:00<? [?it/s]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[7], line 11
#       9         Nmin = n+1
#      10     wes[n+1] = axi.wz(zs[n+1], axiparabola, l_w)
# ---> 11     tes[n+1] = axi.tfz(zs[n+1], axiparabola)-zs[n+1]/c
#      12 ts[n+1] = full_field.get_tpeak(laser) - tps
#      13 print("time:", (time.time()-start)/60, "min")
#
# File ~/jupyter_notebooks/axiparabola_theory.py:226, in tfz(z, axiparabola)
#     224 assert np.all(np.less_equal(z, axiparabola.f0 + axiparabola.delta)), "z needs to be smaller or equal than the f0 + delta."
#     225 assert np.all(np.greater_equal(z, axiparabola.f0)), "z needs to be at least f0"
# --> 226 return tfr(rz(z, axiparabola), axiparabola)
#
# File ~/jupyter_notebooks/axiparabola_theory.py:93, in rz(z, axiparabola)
#      79 def rz(z, axiparabola):
#      80     """The radius at which the pulse is focused to a length z
#      81
#      82     Parameters:
#    (...)
#      91         The radius on the axiparabola
#      92     """
# ---> 93     assert np.all(np.less(z, axiparabola.f0 + axiparabola.delta)), "z needs to be smaller than f0 + delta."
#      94     assert np.all(np.greater_equal(z, axiparabola.f0)), "z needs to be at least f0"
#      95     return np.sqrt((z-axiparabola.f0) / axiparabola.delta * axiparabola.R**2)
#
# AssertionError: z needs to be smaller than f0 + delta.

# %%
fig = plt.figure()
ax = fig.add_subplot()

ax.plot(zs[Nmin:]*1e3, tes[Nmin:]*1e15, label="theoretical t-z/c")
ax.plot(zs*1e3, ts*1e15, ".", label="measured t-z/c")
ax.legend()
ax.set_xlabel("$(z-f_0)$/mm")
ax.set_ylabel("$(t-z/c)$/fs")
plt.show()

# %%
wps = w0 * np.sqrt(1+((zs-f0)/zr)**2)

fig = plt.figure()
ax = fig.add_subplot()

ax.plot(zs[Nmin+1:]*1e3, wes[Nmin+1:]*1e6, label="axiparabol w")
ax.plot(zs*1e3, wps*1e6, label="parabol w")
ax.plot(zs*1e3, ws*1e6, ".", label="measured w")
ax.legend()
ax.set_xlabel("$(z-f_0)$/mm")
ax.set_ylabel("$w/\\mu$m")
# Out:
# Text(0, 0.5, '$w/\\mu$m')

# %%
print("time:", (time.time()-start)/60, "min")
