# %%
import ptime

# %%
import showdata
s1 = "/bigdata/hplsim/external/marqua27/"
s2 = "/bigdata/hplsim/production/marqua27/"
h = "/home/marqua27/jupyter_notebooks/diags/"
end = "/simOutput/openPMD/simData_%T.bp"
filename = s2+"vacuum_propagation/parabola01/run02"+end
#filename = h+"parabol.bp"

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.constants import c
def shouldbe(t):
    """theoretical w"""
    l_w = 10.54e-7
    f0 = 7e-2
    w = 1e-3
    tau = 1.5e-14
    des_dt = 1.39e-16 # PIConGPU Standardwert
    w0 = f0 * l_w / w / np.pi
    zr = np.pi * w0**2/l_w
    z = c*t - c*39450*des_dt
    return w0 * np.sqrt(1+(z/zr)**2)
showdata.plot_w(filename=filename, forward="y", startit=1, unit=2.353377656651999e-05, unitname="$w_0$", comp_func=shouldbe)
ptime.ptime()
# Out:
# calculating w
#   0%|          | 00:00<? [?it/s]
# plotting w
# runtime: 13 min 8 s 45 ms

# %%
showdata.show_file(filename, itstep=1, forward="y", Nz=None, Ny=None, title="Iteration ", titleit=True, linthresh_frac=0.01, 
                   show_time=True, figsize=(10, 6))
ptime.ptime()
# Out:
# iteration: 0
# absolute maximum: 0.0
# nothing to see here
# time showing file: 3 s 572 ms
# iteration: 3945
# absolute maximum: 12657245000000.0
# time showing file: 7 s 106 ms
# iteration: 7890
# absolute maximum: 13233360000000.0
# time showing file: 10 s 800 ms
# iteration: 11835
# absolute maximum: 13879588000000.0
# time showing file: 14 s 605 ms
# iteration: 15780
# absolute maximum: 14544178000000.0
# time showing file: 19 s 564 ms
# iteration: 19725
# absolute maximum: 15131755000000.0
# time showing file: 22 s 588 ms
# iteration: 23670
# absolute maximum: 15734552000000.0
# time showing file: 25 s 682 ms
# iteration: 27615
# absolute maximum: 16227441000000.0
# time showing file: 29 s 692 ms
# iteration: 31560
# absolute maximum: 16569400000000.0
# time showing file: 31 s 728 ms
# iteration: 35505
# absolute maximum: 16735368000000.0
# time showing file: 33 s 713 ms
# iteration: 39450
# absolute maximum: 16728745000000.0
# time showing file: 36 s 617 ms
# iteration: 43395
# absolute maximum: 16613822000000.0
# time showing file: 38 s 746 ms
# iteration: 47340
# absolute maximum: 16326369000000.0
# time showing file: 40 s 691 ms
# iteration: 51285
# absolute maximum: 15893409000000.0
# time showing file: 43 s 487 ms
# iteration: 55230
# absolute maximum: 15355868000000.0
# time showing file: 45 s 806 ms
# iteration: 59175
# absolute maximum: 14767645000000.0
# time showing file: 47 s 782 ms
# iteration: 63120
# absolute maximum: 14184540000000.0
# time showing file: 50 s 370 ms
# iteration: 67065
# absolute maximum: 13561784000000.0
# time showing file: 52 s 617 ms
# iteration: 71010
# absolute maximum: 12913268000000.0
# time showing file: 54 s 837 ms
# iteration: 74955
# absolute maximum: 12304051000000.0
# time showing file: 57 s 557 ms
# iteration: 78900
# absolute maximum: 11719742000000.0
# time showing file: 59 s 564 ms
# runtime: 14 min 7 s 834 ms

# %%
showdata.show_file(filename, iteration=39450, forward="y", title="Iteration ", titleit=True, linthresh_frac=1., 
                   show_SI=True, show_time=True, show_w=True)
ptime.ptime()
# Out:
# iteration: 39450
# absolute maximum: 16728745000000.0
# fitting a gauss-function:
# w1 = 2.353377656651999e-05
# center at 1.7806563706908934e-07 -3.5545556014520704e-07
# calculating statistical deviation:
# w2 = 2.363566950788893e-05
# time showing file: 41 s 63 ms
# runtime: 14 min 48 s 938 ms
