# %%
import time
start = time.time()

from lasy.laser import Laser
from lasy.profiles.combined_profile import CombinedLongitudinalTransverseProfile
from lasy.profiles.longitudinal import GaussianLongitudinalProfile
from lasy.profiles.transverse import SuperGaussianTransverseProfile
from lasy.profiles import GaussianProfile
from lasy.propagators import AngularSpectrumPropagator
from lasy.optical_elements import Axiparabola
from lasy.utils.laser_utils import get_w0

import numpy as np
import matplotlib.pyplot as plt
from scipy.constants import c
import radialGroupDelay as RGD
import full_field
from rectProfile import RectProfile
import axiparabola_theory as axi


dim = "rt"
do_rgd = True

# %%
l_w = 10.54e-7
f0 = 7e-2
delta = 2e-3
w = 1e-3
tau = 1.5e-14
E = 6.2
des_dt = 1.39e-16 # PIConGPU Standardwert
des_dt = 7.3443e-17 # spezieller Wert
w0 = f0 * l_w / w / np.pi
vf = 0.98 * c
print("w0 =", w0)
print("w/w0 =",w/w0)
if dim == "xyt":
    npoints = (int(2*w/w0), int(2*w/w0), 200)
    npoints_prop = (int(10*w/w0), int(10*w/w0), 200)
    hi = (1.1*w, 1.1*w, 4.5*tau)
    lo = (-1.1*w, -1.1*w, -5.*tau)
elif dim == "rt":
    p_per_r = 1.0/3
    picpoints_per_p = 2
    print("points in file:", int(1024/picpoints_per_p))
    spacing = 0.1772e-6 * p_per_r * 3 # PIConGPU Standardwert
    npoints = (int(2*w/spacing), 7500)
    cut_frac = 0.3
    hi = (2*w, 21*tau)
    lo = (0., -15*tau)
    offset_frac = hi[1]/4 / (hi[1]-lo[1])
    print(offset_frac)
print(npoints)

print(np.pi*w0**2/l_w)
print(100000*des_dt*c)

print("time:", (time.time()-start)/60, "min")
# Out:
# w0 = 2.3484903402640077e-05
# w/w0 = 42.580545589452335
# points in file: 512
# 0.14583333333333334
# (11286, 7500)
# 0.0016439432381848056
# 0.0022017657492894005
# time: 0.017659850915273032 min

# %%
profile = CombinedLongitudinalTransverseProfile(l_w, (1,0),
    GaussianLongitudinalProfile(l_w, tau, 0),
    #SuperGaussianTransverseProfile(w, n_order=6),
    RectProfile(w),
    laser_energy=E)
#profile = GaussianProfile(l_w, (1,0), E, w, tau, 0.0)
#propagator = AngularSpectrumPropagator(profile.omega0, "xyt")

laser = Laser(dim, lo, hi, npoints, profile)
#laser.add_propagator(propagator)
#laser.show()
print("time:", (time.time()-start)/60, "min")
# Out:
# time: 0.21412670214970905 min

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(laser.grid.axes[0], SuperGaussianTransverseProfile(w, n_order=6).evaluate(laser.grid.axes[0], np.array([0,])))
ax.set_yscale("log")
plt.show()

# %%
axiparabola = axi.Axiparabola_Ambat(f0, delta, w)

fig = plt.figure()
ax = fig.add_subplot()
ax.plot(laser.grid.axes[0], np.angle(axiparabola.amplitude_multiplier(laser.grid.axes[0], 0, 2*np.pi*c/l_w)), lw=4)
ax.plot(laser.grid.axes[0], np.angle(np.exp(-2j * (2*np.pi*c/l_w/c)*axiparabola.R**2/4/axiparabola.delta*np.log(1+axiparabola.delta/axiparabola.f0*(laser.grid.axes[0]/axiparabola.R)**2)))*np.heaviside(1.7*w-laser.grid.axes[0], 1))
ax.plot(laser.grid.axes[0], np.angle(np.exp(-2j * (2*np.pi*c/l_w/c)*laser.grid.axes[0]**2/4/axiparabola.f0))*np.heaviside(1.7*w-laser.grid.axes[0], 1))
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot()
axis = laser.grid.axes[0][:int(npoints[0]/2)]
ax.plot(axis, (axi.sf(axis, axiparabola) - axis**2/4/axiparabola.f0) / (axis**2/4/axiparabola.f0))
ax.set_xlabel("r/m")
ax.set_ylabel("$(s_f(r) - s_{parabel}(r))/s_{parabel}(r)$")
ax.set_title("relative difference between the axiparabola and a regular parabolic mirror")
plt.show()
# Out:
# /tmp/ipykernel_156823/721738141.py:4: RuntimeWarning: invalid value encountered in divide
#   ax.plot(axis, (axi.sf(axis, axiparabola) - axis**2/4/axiparabola.f0) / (axis**2/4/axiparabola.f0))

# %%
def tau_D(r):
    return RGD.tau_D_const_v(r, vf, axiparabola)

def tau_D2(r):
    return RGD.tau_D_integrated_palastro(r, vf, axiparabola)

def tau_D3(r):
    return RGD.tau_D_integrated_ambat(r, vf, axiparabola)

fig = plt.figure()
ax = fig.add_subplot()
ax.plot(laser.grid.axes[0], tau_D(laser.grid.axes[0])*1e15, label="Oubrerie")
ax.plot(laser.grid.axes[0], tau_D2(laser.grid.axes[0])*1e15, label="Palastro")
ax.plot(laser.grid.axes[0], tau_D3(laser.grid.axes[0])*1e15, label="Ambat")
ax.legend()
ax.set_xlabel("$r$/m")
ax.set_ylabel("$\\tau_D(r)$/fs")
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(laser.grid.axes[0], tau_D2(laser.grid.axes[0])- tau_D(laser.grid.axes[0]), label="2-1")
ax.plot(laser.grid.axes[0], tau_D3(laser.grid.axes[0])- tau_D2(laser.grid.axes[0]), label="3-2")
ax.plot(laser.grid.axes[0], tau_D(laser.grid.axes[0])- tau_D3(laser.grid.axes[0]), label="1-3")
ax.legend()
plt.show()

# %%
if do_rgd:
    radial_delay = RGD.RadialGroupDelay(tau_D, l_w)
    laser.apply_optics(radial_delay)
    laser.show()
    def ztime(z):
        return (z-axiparabola.f0)/vf + axiparabola.f0/c
else:
    def ztime(z):
        r2 = (z-axiparabola.f0) / axiparabola.delta*axiparabola.R**2
        return 1/c*(z+r2/2/z-2*axiparabola.R**2/4/axiparabola.delta*np.log(1+axiparabola.delta/axiparabola.f0*r2/axiparabola.R**2))
print("time:", (time.time()-start)/60, "min")
# Out:
# time: 0.576529876391093 min

# %%
laser.apply_optics(axiparabola)
laser.show()
print("time:", (time.time()-start)/60, "min")
# Out:
# time: 1.4234134833017984 min

# %%
full_field.show_field(laser, Nt=None, Nr=npoints[0]//2, offset_frac=2*offset_frac, forced_dt=des_dt, linthresh_frac=0.000001)
# Out:
# Extracting full field
# Nt = 7352
#   0%|          | 00:00<? [?it/s]
# Displaying

# %%
if dim == "xyt":
    import regrid
    laser = regrid.regrid_laser(laser, Nx=npoints_prop[0])
    laser = regrid.regrid_laser(laser, Ny=npoints_prop[1])
    laser.show()
    print("time:", (time.time()-start)/60, "min")

# %%
laser.propagate(f0)
laser.show()
print("time:", (time.time()-start)/60, "min")
# Out:
# Available backends are: NP
# NP is chosen
#   0%|          | 00:00<? [?it/s]
# time: 52.085728987058005 min

# %%
full_field.show_field(laser, Nt=5000, Nr=5000, offset_frac=1*offset_frac, forced_dt=des_dt, linthresh_frac=0.01, title="At the focus of the axiparabola")
print("w =", get_w0(laser.grid, laser.dim))
# Out:
# Extracting full field
# Warning: Nt and forced_dt given. Can not return the entire field, just 68.00 percent.
# Offsetting by 14.58 percent of the original field
#   0%|          | 00:00<? [?it/s]
# Displaying
# w = 0.0001424286580207014

# %%
if dim == "xyt":
    laser = regrid.cutgrid_laser(laser, Nx=400, Ny=400)

# %%
print(dhfjuh)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 print(dhfjuh)
#
# NameError: name 'dhfjuh' is not defined

# %%
full_field.laser_to_openPMD(laser, "fl_foc_noRGD3", Nt=3072, Nx=int(1024/picpoints_per_p), Ny=int(1024/picpoints_per_p), conversion_safety=1.1,
                            points_between_r=p_per_r, forced_dt=des_dt, offset_frac=1*offset_frac, file_format="bp", data_step=picpoints_per_p, show=True)
laser.show()
print("time:", (time.time()-start)/60, "min")

# %%
print(laser.grid.npoints)
tps = full_field.get_tpeak(laser)
print(tps)
for n in range(3):
    laser.propagate(delta/3)
    laser.show()
    print("t:",full_field.get_tpeak(laser)-tps)
    print("t expect", ztime(f0+(n+1)*delta/3) - (f0+(n+1)*delta/3) / c)
    print("w:",get_w0(laser.grid, laser.dim))
    print("w expect", l_w*axiparabola.f0/np.pi/axiparabola.R*np.sqrt(axiparabola.delta/((n+1)*delta/3)))
    print(f0+(n+1)*delta/3)
    print("time:", (time.time()-start)/60, "min")
# Out:
# [11286, 7500]
# 6.638946584230643e-14
#   0%|          | 00:00<? [?it/s]
# t: 2.0509227243276145e-15
# t expect 4.5382870095000315e-14
# w: 0.0001433605898671715
# w expect 4.0677045904219814e-05
# 0.07066666666666667
# time: 102.6176274339358 min
#   0%|          | 00:00<? [?it/s]
# t: -3.8622190093199246e-16
# t expect 9.076574019000063e-14
# w: 0.00014443555475311136
# w expect 2.876301499751031e-05
# 0.07133333333333335
# time: 147.6239666302999 min
#   0%|          | 00:00<? [?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 5
#       3 print(tps)
#       4 for n in range(3):
# ----> 5     laser.propagate(delta/3)
#       6     laser.show()
#       7     print("t:",full_field.get_tpeak(laser)-tps)
#
# File ~/miniforge3/envs/picongpu/lib/python3.10/site-packages/lasy/laser.py:264, in Laser.propagate(self, distance, **kwargs)
#     261     propagator = AxipropPropagator()
#     262     self.add_propagator(propagator)
# --> 264 grid_out = self.propagator.propagate(
#     265     self.grid, self.dim, self.profile.omega0, distance=distance, **kwargs
#     266 )
#     267 self.grid = grid_out
#
# File ~/miniforge3/envs/picongpu/lib/python3.10/site-packages/lasy/propagators/axiprop_propagators.py:206, in AxipropPropagator.propagate(self, grid_in, dim, omega0, distance, grid_out, verbose, nr_boundary)
#     203     grid_out = deepcopy(grid_in)
#     205 if dim == "rt":
# --> 206     field = self._propagate_mrt(
#     207         distance, grid_in, omega0, grid_out, verbose, nr_boundary
#     208     )
#     209 else:
#     210     field = self._propagate_xyt(distance, grid_in, omega0, verbose, nr_boundary)
#
# File ~/miniforge3/envs/picongpu/lib/python3.10/site-packages/lasy/propagators/axiprop_propagators.py:263, in AxipropPropagator._propagate_mrt(self, distance, grid_in, omega0, grid_out, verbose, nr_boundary)
#     260 prop_rt = self.props_rt[im]
#     262 container_in = containers_in[im]
# --> 263 Field_ft_new = prop_rt.step(
#     264     container_in.Field_ft, distance, overwrite=False, show_progress=verbose
#     265 )
#     267 laser_loc = ScalarFieldEnvelope(
#     268     container_in.k0, container_in.t + distance / c, nr_boundary
#     269 )
#     271 laser_loc.import_field_ft(
#     272     Field_ft_new, r_axis=prop_rt.r_new, transform=True, make_copy=False
#     273 )
#
# File ~/miniforge3/envs/picongpu/lib/python3.10/site-packages/axiprop/steppers.py:84, in StepperNonParaxial.step(self, u, dz, overwrite, show_progress)
#      81 phase_loc = self.bcknd.sqrt( (phase_loc>=0.)*phase_loc )
#      82 self.u_ht *= self.bcknd.exp( 1j * dz * phase_loc )
# ---> 84 self.iTST()
#      86 if on_device:
#      87     u_step[ikz] = self.u_iht.copy()
#
# File ~/miniforge3/envs/picongpu/lib/python3.10/site-packages/axiprop/lib.py:347, in PropagatorResampling.iTST(self)
#     343 def iTST(self):
#     344     """
#     345     Inverse QDHT transform.
#     346     """
# --> 347     self.u_iht = self.iTST_matmul(self.invTM, self.u_ht, self.u_iht)
#
# File ~/miniforge3/envs/picongpu/lib/python3.10/site-packages/axiprop/backends.py:63, in BACKEND_NP.make_matmul.<locals>.matmul(a, b, c)
#      62 def matmul(a, b, c):
# ---> 63     c = np.dot(a, b, out=c)
#      64     return c
#
# KeyboardInterrupt:

# %%
laser.propagate(delta)
laser.show()
print("time:", (time.time()-start)/60, "min")

# %%
laser.propagate(delta)
laser.show()
print("time:", (time.time()-start)/60, "min")
